# %% [markdown]
#  # EDA

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import zipfile
zip_path = r"C:\Users\Shree\Downloads\TwYntYAlAcoQRutU (1).zip"
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall("heart_disease")

# %%
# import os 
# os.listdir("heart_disease")   # see all files 
# with open ("heart_disease/heart-disease.names","r")as file:
#     content = file.read()
#     print (content)

# %%
columns = [
       "age" ,      
       "sex",    
       "cp",   
        "trestbps", 
       "chol",     
       "fbs",      
       "restecg",   
        "thalach",   
       "exang",     
        "oldpeak",   
        "slope",     
        "ca",        
        "thal",
        "target"       
]

# %%
df = pd.read_csv("heart_disease/processed.cleveland.data", header = None, names=columns)

# %%
df.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  target
# 0    3.0  0.0  6.0       0
# 1    2.0  3.0  3.0       2
# 2    2.0  2.0  7.0       1
# 3    3.0  0.0  3.0       0
# 4    1.0  0.0  3.0       0

# %%
df.tail()
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  target
# 298    2.0  0.0  7.0       1
# 299    2.0  2.0  7.0       2
# 300    2.0  1.0  7.0       3
# 301    2.0  1.0  3.0       1
# 302    1.0    ?  3.0       0

# %%
df.shape
# Out:
# (303, 14)

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  target    303 non-null    int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 33.3+ KB

# %%
# we have to check ca,and thal clocals because there dtype is object(2) data type does not match what it should logically be
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
# df.describe()

# %%
df = pd.read_csv("heart_disease/processed.cleveland.data", header = None, names=columns, na_values="?")
df.head()
df.tail()
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  target
# 298    2.0  0.0   7.0       1
# 299    2.0  2.0   7.0       2
# 300    2.0  1.0   7.0       3
# 301    2.0  1.0   3.0       1
# 302    1.0  NaN   3.0       0

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
df.shape  # we have a null values in our data so have to replace it or drop it
# Out:
# (303, 14)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Data Cleaning

# %%
clean_df = df.copy()
clean_df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          4
# thal        2
# target      0
# dtype: int64

# %%
clean_df = clean_df.dropna()  # i choose this method because percentage of null values Very small size: Less than 2% of data is very small.

# %%
clean_df.shape
clean_df.describe()
clean_df.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps    float64
# chol        float64
# fbs         float64
# restecg     float64
# thalach     float64
# exang       float64
# oldpeak     float64
# slope       float64
# ca          float64
# thal        float64
# target        int64
# dtype: object

# %%
def replace_outliers(data, column, method="median"):
    #calculate Q1 ,Q3 , IQRabs
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)

    IQR = Q3-Q1

    lower = Q1 - 1.5*IQR 
    upper = Q3 + 1.5*IQR

    # replace 
    if method =="median":
        replace_value = data[column].median()
    elif method =="mode":
        replace_value = data[column].mode()[0]
    else:
        raise ValueError("Method should be 'median' or 'mode'")

    outliers = data.loc[
         (data[column]<lower) | (data[column]>upper),
         column
    ].copy()

    # 
    if len(outliers)> 0:
        print(f"\nColumn: {column}")
        print(f"Replacement Method : {method}")
        print(f"Replacement Value: {replace_value}")
        print("Replaced Values:")

        for index, value in outliers.items():
            print (f"Row {index}:{value}--->{replace_value}")
    else:
        print(f"\nColumn:{column}")
        print("No Outliers Found.")

    # Replace Outliers 
    data [column] = np.where((data[column]<lower) |  (data[column]>upper),replace_value,data[column] )
    return data

# %%
columns = [
        "age" , 
        "trestbps", 
        "chol",              
        "thalach",     
        "oldpeak"
]  
for col in columns:
    clean_df = replace_outliers (
    clean_df,
    col,
    method ="median"
   )
# Out:
# Column:age
# No Outliers Found.
#
# Column: trestbps
# Replacement Method : median
# Replacement Value: 130.0
# Replaced Values:
# Row 14:172.0--->130.0
# Row 83:180.0--->130.0
# Row 126:200.0--->130.0
# Row 172:174.0--->130.0
# Row 183:178.0--->130.0
# Row 188:192.0--->130.0
# Row 201:180.0--->130.0
# Row 213:178.0--->130.0
# Row 231:180.0--->130.0
#
# Column: chol
# Replacement Method : median
# Replacement Value: 243.0
# Replaced Values:
# Row 48:417.0--->243.0
# Row 121:407.0--->243.0
# Row 152:564.0--->243.0
# Row 173:394.0--->243.0
# Row 181:409.0--->243.0
#
# Column: thalach
# Replacement Method : median
# Replacement Value: 153.0
# Replaced Values:
# Row 245:71.0--->153.0
#
# Column: oldpeak
# Replacement Method : median
# Replacement Value: 0.8
# Replaced Values:
# Row 91:6.2--->0.8
# Row 123:5.6--->0.8
# Row 183:4.2--->0.8
# Row 191:4.2--->0.8
# Row 285:4.4--->0.8

# %%
df.duplicated().sum()  # there is no duplicates
# Out:
# np.int64(0)

# %% [markdown]
# # SQL database

# %%
import sqlite3
conn = sqlite3.connect("heart_disease.db")

# %%
clean_df.to_sql(
    "heart_data",
    conn,
    if_exists="replace",
    index=False
)
# Out:
# 297

# %%
query = "SELECT * FROM heart_data;"
table = pd.read_sql(query,conn)
print(table)
# Out:
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 292  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 293  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 294  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 295  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 296  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
# Queryabs 1-6

query1 = """
SELECT * 
FROM heart_data 
WHERE age > 50;
"""

# qquery 2 
query2 ="""
SELECT sex, COUNT(*) AS Total_Patients
FROM heart_data 
Group BY sex;
"""
# query 3 
query3 = """
SELECT cp, AVG(chol) AS Avg_Cholesterol
FROM heart_data 
GROUP BY cp 
HAVING AVG(chol)>200;
"""

#query4
query4 ="""
SELECT age, chol, thalach
FROM heart_data 
ORDER BY chol DESC
LIMIT 10;
"""
# qUERY 5
query5 ="""
SELECT * 
FROM heart_data
WHERE AGE >50
AND target =1;
"""

# query 6
query6 ="""
SELECT target,AVG(thalach) as Avg_Heart_Rate
FROM heart_data 
GROUP BY target;
"""

queries = [ query1, query2, query3, query4, query5, query6]

for i, query in enumerate(queries, start=1):
    print("\n===========")
    print(f"QUERY{i} RESULT")
    print("==========")

    result = pd.read_sql(query, conn)
    display(result)
# Out:
# ...
# QUERY1 RESULT
# ...
#       age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    56.0  1.0  2.0     120.0  236.0  0.0      0.0    178.0    0.0      0.8
# 4    62.0  0.0  4.0     140.0  268.0  0.0      2.0    160.0    0.0      3.6
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 200  59.0  1.0  4.0     164.0  176.0  1.0      2.0     90.0    0.0      1.0
# 201  57.0  0.0  4.0     140.0  241.0  0.0      0.0    123.0    1.0      0.2
# 202  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 203  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 204  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
#
#      slope   ca  thal  target
# ...

# %%
# Create queries.sql file using Python

queries = """
-- Query 1:
-- Filter patients whose age is greater than 50

SELECT *
FROM heart_data
WHERE age > 50;


-- Query 2:
-- Count total patients according to gender

SELECT 
    sex,
    COUNT(*) AS Total_Patients
FROM heart_data
GROUP BY sex;


-- Query 3:
-- Average cholesterol by chest pain type with HAVING condition

SELECT 
    cp,
    AVG(chol) AS Avg_Cholesterol
FROM heart_data
GROUP BY cp
HAVING AVG(chol) > 200;


-- Query 4:
-- Top 10 patients with highest cholesterol

SELECT 
    age,
    chol,
    thalach
FROM heart_data
ORDER BY chol DESC
LIMIT 10;


-- Query 5:
-- Patients older than 50 with heart disease

SELECT *
FROM heart_data
WHERE age > 50
AND target = 1;


-- Query 6:
-- Average maximum heart rate based on heart disease status

SELECT 
    target,
    AVG(thalach) AS Avg_Heart_Rate
FROM heart_data
GROUP BY target;
"""

# Write SQL queries into file
with open("queries.sql", "w", encoding="utf-8") as file:
    file.write(queries)

print("queries.sql file created successfully!")
# Out:
# queries.sql file created successfully!

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### BOX Plot

# %%
sns.set_style("whitegrid")

plt.figure(figsize=(8,5))

sns.boxplot(
    y=clean_df["chol"]
)
plt.title("Box Plot of Cholesterol Levels")
plt.ylabel("Cholesterol")
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.figure(figsize=(8,6))
plt.hist(
    clean_df["age"],
    edgecolor="black"
)
plt.title(" Age Distribution of Patients")
plt.xlabel("Age")
plt.ylabel("Number of Patients")
plt.show()

# %% [markdown]
# ### Bar Chart

# %%
plt.figure(figsize=(8,6))
clean_df["target"].value_counts().plot(kind="bar", color=["green","red"])
plt.title("Heart Disease Count")
plt.xlabel("Target(0=No Disease, 1= Disease)")
plt.ylabel("Number of Patients")
plt.xticks(rotation= 0)
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data = clean_df, x="age", y="thalach",hue="target")
plt.title(" Age VS Maximum Heart Rate")
plt.xlabel("Age")
plt.ylabel("Maximum Hrart Rate(thalach)")
plt.show()

# %% [markdown]
# ### Group By Bar Chart

# %%
group_data = clean_df.groupby("sex")["chol"].mean()
plt.figure(figsize=(8,6))
group_data.plot(kind="bar", color=["blue","pink"])
plt.title("Average Cholesterol by Gender ")
plt.xlabel("sex(0=Female,1= Male)")
plt.ylabel("Average cholesterol")
plt.xticks(rotation= 0)
plt.show()

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Shree\Capstone Project\Part 1

# %%
import os
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'Data Engineering, SQL Querying & Exploratory Analysis.ipynb', 'heart_disease', 'heart_disease.db', 'queries.sql', 'README.md', 'requirements.txt']

# %%
# Empty text file तयार करा
with open("requirements.txt", "w") as f:
    pass

print("Empty requirements.txt file created successfully!")
# Out:
# Empty requirements.txt file created successfully!

# %%
# # Create an empty README.md file
# with open("README.md", "w", encoding="utf-8") as f:
#     pass

# print("README.md created successfully!")
